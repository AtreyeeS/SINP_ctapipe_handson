# %% [markdown]
# # Effect of camera geometries
#
# What is the ideal pixel shape of a camera?
#
# For this, we will simulate toy models on different camera geometries, and find how well they can be reconstructed.
#
# 1. A hexagonal layout
# 2. A square layout
# 3. A staggered square layout
#
# For now, you can consider a total size of 30 cm by 30 cm for the camera
#
# 1. Use pixel size = 20 mm
# 2. Use pixel size = 2 mm
#
# Compare the effect of the geometries in the 2 cases
